# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# %cd "/content/drive/MyDrive/Colab2"
#!ls
# !apt-get install -qq git
# !git remote remove main
#!git clone https://github.com/JiyeongHEO/deepLearningFromScratch.git
# !ls -ltr
# !git init
# !git config --global user.email "lheojyl@gmail.com"
# !git config --global user.name "JiyeongHEO"
# !git branch -m main
# !git config --global init.defaultBranch main
#!git log --oneline --graph --all

# !git add .
# !git status -s
# !git commit -m "밑바닥부터 시작하는.."
#!git remote add main https://github.com/JiyeongHEO/deepLearningFromScratch.git
# !git branch
# !git add .
# !git commit -m "밑바닥부터 시작하는..2"
# !git branch -a -v


# !git branch -M main
# !git config credential.helper store --global
# !git push -u main
# !git push main
# !git reset HEAD
# !git rm --cached deepLearningFromScratch


# !rm -rf .git
#!rm -rf deepLearningFromScratch
# !git remote remove origin
# !git remote add main https://github.com/JiyeongHEO/deepLearningFromScratch.git
# !git init
# !git remote -v
# !git push -u origin main
# Out:
# /content/drive/MyDrive/Colab2
# [main_local 0bb6b5c] 밑바닥부터 시작하는..
#  1 file changed, 1 insertion(+), 1 deletion(-)
#  rewrite "\341\204\206\341\205\265\341\207\200\341\204\207\341\205\241\341\204\203\341\205\241\341\206\250\341\204\207\341\205\256\341\204\220\341\205\245\341\204\211\341\205\265\341\204\214\341\205\241\341\206\250\341\204\222\341\205\241\341\204\202\341\205\263\341\206\253/ch00.ipynb" (86%)
# fatal: could not read Username for 'https://github.com': No such device or address
